# %% [markdown]
# Practice making a decision tree that compares four inputs (total, per90, l5, and opponent allowed)

# %%
import json, csv
import pandas as pd
from constants import *
import numpy as np
from scipy.stats import poisson

def poisson_over_likelyhood(mean, target):
    return 1 - poisson.cdf(target, mean)
# Out:
# C:\Users\Aaron\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\scipy\__init__.py:169: UserWarning: A NumPy version >=1.18.5 and <1.26.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
players = pd.read_csv("Premier_League_Player_Stats.csv")
PP_lines = pd.read_csv("pp_lines.csv")
last5 = pd.read_csv("Premier_League_Last_Five_Stats.csv")
teams = pd.read_csv("Premier_League_Team_Stats.csv")

merged = pd.merge(players, PP_lines, on="name")
merged = pd.merge(merged, last5, on="name", suffixes=("", "_last5"))

#TODO: Make sure all opponents and teams are in the same format from PP to FBREF

merged = pd.merge(merged, teams, left_on="opponent", right_on="name", suffixes=("", "_opposing_team"))
merged
# Out:
#                   name     team  games  minutes  gk_saves  clearances  \
# 0      Conor Gallagher  Chelsea     29     2421       NaN        15.0
# 1          Axel Disasi  Chelsea     28     2480       NaN        97.0
# 2       Moises Caicedo  Chelsea     27     2173       NaN        32.0
# 3       Enzo Fernandez  Chelsea     27     2143       NaN        28.0
# 4      Nicolas Jackson  Chelsea     27     2084       NaN        15.0
# 5         Thiago Silva  Chelsea     24     2073       NaN       117.0
# 6          Cole Palmer  Chelsea     26     1993       NaN        11.0
# 7      Raheem Sterling  Chelsea     27     1851       NaN         8.0
# 8           Malo Gusto  Chelsea     22     1528       NaN        36.0
# 9      Mykhailo Mudryk  Chelsea     24     1080       NaN         6.0
# 10        Noni Madueke  Chelsea     15      461       NaN         8.0
# 11     Jordan Pickford  Everton     31     2790      91.0        16.0
# 12     James Tarkowski  Everton     31     2789       NaN       148.0
# 13        James Garner  Everton     30     2521       NaN        43.0
# 14  Jarrad Branthwaite  Everton     28     2520       NaN       130.0
# 15       Dwight McNeil  Everton     28     2284       NaN        29.0
# 16  Abdoulaye Doucoure  Everton     25     2059       NaN        13.0
# 17        Ashley Young  Everton     24     1719       NaN        37.0
# 18                Beto  Everton     26      826       NaN        14.0
#
#     tackles  assisted_shots  fouled  shots  ...  tackles_opposing_team  \
# 0      70.0            45.0    42.0   40.0  ...                    610
# 1      31.0             3.0    17.0   15.0  ...                    610
# 2      62.0            15.0    36.0    8.0  ...                    610
# 3      48.0            32.0    31.0   44.0  ...                    610
# 4      14.0            26.0    23.0   57.0  ...                    610
# 5      26.0             6.0     8.0   10.0  ...                    610
# 6      21.0            52.0    20.0   69.0  ...                    610
# 7      20.0            26.0    37.0   46.0  ...                    610
# 8      50.0            29.0    27.0   11.0  ...                    610
# 9      20.0            20.0    20.0   24.0  ...                    610
# 10      9.0             8.0    10.0   16.0  ...                    610
# 11      0.0             4.0     6.0    0.0  ...                    531
# 12     49.0            19.0    18.0   22.0  ...                    531
# 13     73.0            38.0    36.0   33.0  ...                    531
# 14     53.0             3.0    16.0    9.0  ...                    531
# 15     34.0            51.0    25.0   47.0  ...                    531
# 16     36.0            30.0     5.0   40.0  ...                    531
# 17     35.0            20.0    19.0   12.0  ...                    531
# 18     14.0            11.0    18.0   37.0  ...                    531
#
#     interceptions_opposing_team  clearances_opposing_team  tackles_against  \
# 0                           308                       699              491
# 1                           308                       699              491
# 2                           308                       699              491
# 3                           308                       699              491
# 4                           308                       699              491
# 5                           308                       699              491
# 6                           308                       699              491
# 7                           308                       699              491
# 8                           308                       699              491
# 9                           308                       699              491
# 10                          308                       699              491
# 11                          237                       585              585
# 12                          237                       585              585
# 13                          237                       585              585
# 14                          237                       585              585
# 15                          237                       585              585
# 16                          237                       585              585
# 17                          237                       585              585
# 18                          237                       585              585
#
#     interceptions_against  clearances_against  fouls_opposing_team  \
# 0                     208                 743                  376
# 1                     208                 743                  376
# 2                     208                 743                  376
# 3                     208                 743                  376
# 4                     208                 743                  376
# 5                     208                 743                  376
# 6                     208                 743                  376
# 7                     208                 743                  376
# 8                     208                 743                  376
# 9                     208                 743                  376
# 10                    208                 743                  376
# 11                    316                 577                  365
# 12                    316                 577                  365
# 13                    316                 577                  365
# 14                    316                 577                  365
# 15                    316                 577                  365
# 16                    316                 577                  365
# 17                    316                 577                  365
# 18                    316                 577                  365
#
#     fouled_opposing_team fouls_against  fouled_against
# 0                    289           301             365
# 1                    289           301             365
# 2                    289           301             365
# 3                    289           301             365
# 4                    289           301             365
# 5                    289           301             365
# 6                    289           301             365
# 7                    289           301             365
# 8                    289           301             365
# 9                    289           301             365
# 10                   289           301             365
# 11                   345           358             350
# 12                   345           358             350
# 13                   345           358             350
# 14                   345           358             350
# 15                   345           358             350
# 16                   345           358             350
# 17                   345           358             350
# 18                   345           358             350
#
# [19 rows x 76 columns]

# %%
results = []
not_available = ['Shots On Target']

for index, row in merged.iterrows():
    # Access the values of each column in the current row
    name = row['name']

    for pp_stat_type in pp_to_fbref_stats.keys():
        # failsafe 
        if pp_stat_type not in row:
            continue

        if row[pp_stat_type] <= 0:
            continue

        if pp_stat_type in not_available:
            continue

        # Create a dictionary to store the result
        result_dict = {
            'name': name,
            'stat': pp_stat_type,
            'line': row[pp_stat_type]
        }

        # Get the FBref stat type that corresponds to the current PP stat type
        fbref_stat_type = pp_to_fbref_stats[pp_stat_type]

        # Get the value of the FBref stat type for the current player
        fbref_stat_value = row[fbref_stat_type]

        # Add the FBref stat value to the result dictionary
        result_dict['per90'] = fbref_stat_value * 90 / row['minutes']
        result_dict['perGame'] = fbref_stat_value / row['games']

        # Get the last 5 games stats
        last5_stat_type = fbref_stat_type + "_last5"
        last5_stat_value = row[last5_stat_type]

        # Add the last 5 games stats to the result dictionary
        result_dict['last5_per90'] = last5_stat_value * 90 / row['minutes_last5']
        result_dict['last5_perGame'] = last5_stat_value / row['games_last5']

        # Get the opposing team's FBref stat value
        opposing_team_fbref_stat_value = row[fbref_stat_type + "_opposing_team"]
        result_dict['opposing_team_relative_value'] = opposing_team_fbref_stat_value

        # Append the dictionary to the results list
        results.append(result_dict)

# Convert the results list into a dataframe
df = pd.DataFrame(results).dropna()

df
# Out:
#                    name              stat  line      per90    perGame  \
# 5       Conor Gallagher             Shots   1.5   1.486989   1.379310
# 8       Conor Gallagher             Fouls   2.0   2.379182   2.206897
# 15          Axel Disasi             Shots   0.5   0.544355   0.535714
# 22       Moises Caicedo           Tackles   2.0   2.567879   2.296296
# 35       Enzo Fernandez             Shots   2.0   1.847877   1.629630
# 36       Enzo Fernandez  Passes Attempted  79.5  75.804946  66.851852
# 45      Nicolas Jackson             Shots   2.5   2.461612   2.111111
# 51         Thiago Silva        Clearances   3.5   5.079595   4.875000
# 63          Cole Palmer    Shots Assisted   2.0   2.348219   2.000000
# 65          Cole Palmer             Shots   3.5   3.115906   2.653846
# 66          Cole Palmer  Passes Attempted  47.5  50.215755  42.769231
# 69          Cole Palmer             Goals   0.5   0.722529   0.615385
# 75      Raheem Sterling             Shots   2.0   2.236629   1.703704
# 82           Malo Gusto           Tackles   2.0   2.945026   2.272727
# 85           Malo Gusto             Shots   0.5   0.647906   0.500000
# 95      Mykhailo Mudryk             Shots   1.5   2.000000   1.000000
# 105        Noni Madueke             Shots   2.0   3.123644   1.066667
# 110     Jordan Pickford      Goalie Saves   3.5   2.935484   2.935484
# 122     James Tarkowski           Tackles   1.5   1.581212   1.580645
# 125     James Tarkowski             Shots   0.5   0.709932   0.709677
# 132        James Garner           Tackles   2.0   2.606109   2.433333
# 136        James Garner  Passes Attempted  30.5  37.627925  35.133333
# 141  Jarrad Branthwaite        Clearances   5.0   4.642857   4.642857
# 142  Jarrad Branthwaite           Tackles   2.0   1.892857   1.892857
# 155       Dwight McNeil             Shots   1.5   1.852014   1.678571
# 168  Abdoulaye Doucoure             Fouls   1.5   1.966974   1.800000
# 173        Ashley Young    Shots Assisted   0.5   1.047120   0.833333
# 185                Beto             Shots   2.0   4.031477   1.423077
#
#      last5_per90  last5_perGame  opposing_team_relative_value
# 5       1.777778            1.6                           424
# 8       0.000000            0.0                           376
# 15      1.200000            1.2                           424
# 22      2.138229            2.2                           610
# 35      2.896996            3.0                           424
# 36     84.206009           87.2                         12583
# 45      3.511294            3.8                           424
# 51      0.000000            0.0                           699
# 63      0.000000            0.0                           286
# 65      2.576687            2.8                           424
# 66     48.404908           52.6                         12583
# 69      0.368098            0.4                            32
# 75      2.665148            2.6                           424
# 82      2.683486            2.6                           610
# 85      0.619266            0.6                           424
# 95      1.675532            1.4                           424
# 105     4.046763            5.0                           424
# 110     3.000000            3.0                           102
# 122     1.161290            1.2                           531
# 125     0.580645            0.6                           413
# 132     1.690141            1.6                           531
# 136    24.929577           23.6                         18501
# 141     0.000000            0.0                           585
# 142     1.400000            1.4                           531
# 155     2.471396            2.4                           413
# 168     0.000000            0.0                           365
# 173     0.000000            0.0                           322
# 185     4.052795            5.8                           413
